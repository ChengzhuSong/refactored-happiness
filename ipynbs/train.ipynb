# %%
import pandas as pd

df = pd.read_csv("../data/crello/crello_train_elements_per_image.csv")
df.head(50)
# Out:
#     poster_row_idx                 poster_id  element_index  \
# 0                0  5a217b64d8141396fe9a2d7d              0
# 1                0  5a217b64d8141396fe9a2d7d              1
# 2                0  5a217b64d8141396fe9a2d7d              2
# 3                0  5a217b64d8141396fe9a2d7d              3
# 4                0  5a217b64d8141396fe9a2d7d              4
# 5                0  5a217b64d8141396fe9a2d7d              5
# 6                0  5a217b64d8141396fe9a2d7d              6
# 7                0  5a217b64d8141396fe9a2d7d              7
# 8                1  5ea84494499b85dcc7eaa006              0
# 9                1  5ea84494499b85dcc7eaa006              1
# 10               1  5ea84494499b85dcc7eaa006              2
# 11               1  5ea84494499b85dcc7eaa006              3
# 12               1  5ea84494499b85dcc7eaa006              4
# 13               1  5ea84494499b85dcc7eaa006              5
# 14               1  5ea84494499b85dcc7eaa006              6
# ...
